# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.0

# %%
def multiply (a,b):
    print("Multiply: ",a*b)

def add (a,b):
    print ("Add: ",a+b)

def subtract (a,b):
    print ("Subtract: ",a-b)

def divide (a,b):
    print ("Divide: ",a/b)

def calculator(a,b,operation):
    if operation == "+":
        add(a,b)
    elif operation == "-":
        subtract(a,b)
    elif operation == "*":
        multiply(a,b)
    elif operation == "/":
        divide(a,b)
    else:
        print("Invalid Operation")

calculator(5,10,"+")
# Out:
# Add:  15

# %%
print("Servas Matteo")

def calc (s):
    
    try:
        key, value = s.split("/")
    except ValueError:
        pass
    else:
        print ("Divide: " ,int(key)/int(value))
    
    try:
        key, value = s.split("+")
    except ValueError:
        pass
    else:
        print ("Sum: " ,int(key)+int(value))

    try:
        key, value = s.split("-")
    except ValueError:
        pass
    else:
        print ("Subtract: " ,int(key)-int(value))

    try:
        key, value = s.split("*")
    except ValueError:
        pass
    else:
        print ("Multiply: " ,int(key)*int(value))
    
    try:
        key, value = s.split("^")
    except ValueError:
        pass
    else:
        if (int(key)*int(key)) < 100:
            print ("Rechne selber du Pfosten")
        else:
            print ("Pow: " ,int(key)*int(key))

s = input("Gib deine Rechnung ein: ")

calc(s)
# Out:
# Servas Matteo
# Sum:  6
